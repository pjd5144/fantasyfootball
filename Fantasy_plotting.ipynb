# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.chdir('/Users/peterdudenas/Desktop/fantasyfootball/PBR')
df = pd.read_csv('TE_rankings.csv')
df2 = pd.read_csv('WR_rankings.csv')
df3 = pd.read_csv('RB_rankings.csv')
df4 = pd.read_csv('QB_rankings.csv')
fig1 =plt.figure(figsize=(10.125, 9), dpi= 150, facecolor='w', edgecolor='k')
plt.subplot(221)
plt.scatter(df4['avg_pts'],df4['cv'])
plt.ylim(ymin=0,ymax=5)
plt.xlim(xmax=22)
plt.title('QB')
plt.ylabel('Coefficient of Variation')
plt.xlabel('Average Points')
plt.subplot(222)
plt.scatter(df3['avg_pts'],df3['cv'])
plt.ylim(ymin=0,ymax=5)
plt.xlim(xmax=22)
plt.title('RB')
plt.ylabel('Coefficient of Variation')
plt.xlabel('Average Points')
plt.subplot(223)
plt.scatter(df2['avg_pts'],df2['cv'])
plt.ylim(ymin=0,ymax=5)
plt.xlim(xmax=22)
plt.title('WR')
plt.ylabel('Coefficient of Variation')
plt.xlabel('Average Points')
plt.subplot(224)
plt.scatter(df['avg_pts'],df['cv'])
plt.title('TE')
plt.ylim(ymin=0,ymax=5)
plt.xlim(xmax=22)
plt.ylabel('Coefficient of Variation')
plt.xlabel('Average Points')
plt.show()
